# %%
import pandas as pd
import numpy as np
import os

# %%
# exp_data\tracking\latency\GT-A_asterios-paw_latency.npy
path= os.path.join(os.getcwd(), 'exp_data', 'tracking', 'latency', 'GT-A_asterios-paw_latency.npy')
data = np.load(path, allow_pickle=True)

# %%
df = pd.DataFrame(data)
df

# %%
# Get mean, std and plot
mean = df.mean()
std = df.std()
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.boxplot(df, vert=False)
plt.title('Latency Data Distribution')  
plt.xlabel('Latency (ms)')
plt.show()
data = np.load(path, allow_pickle=True)
